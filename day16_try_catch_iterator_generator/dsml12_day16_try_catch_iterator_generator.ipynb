# %%
num = [1,2,3]
it = iter(num)

# %%
print(next(it))
# Out:
# 1

# %%
# iterable
lst = [1,2,3]
for i in lst:
  print(i)
# Out:
# 1
# 2
# 3

# %%
num = [1,2,3]
it = iter(num)

# %%
it

# %%
next(it)
# Out:
# 1

# %%
for i in it:
  print(i)
# Out:
# 2
# 3

# %%
def count_up(n):
  i = 1
  while i <= n:
    yield i
    i += 1

# %%
gent = count_up(3)

# %%
gent
# Out:
# <generator object count_up at 0x78d07d6ab880>

# %%
print(next(gent))
# Out:
# 1

# %%
print(next(gent))
# Out:
# 2

# %%
print(next(gent))
# Out:
# 3

# %%
# try:
# expect
# else:
# finally

try:
  numerator = int(input("Enter a number to divide"))
  denominator = int(input("Enter a number to divide by:"))
  result = numerator/denominator
except ZeroDivisionError:
  print("Error: Cannot divide by zero!")
except ValueError:
  print("Error: Invalid input. Please enter a valid number")
else:
  print(f"The result is {result}")
finally:
  print("Execution complete.")
# Out:
# Enter a number to divide10
# Enter a number to divide by:5
# The result is 2.0
# Execution complete.

# %%
# ZeroDivisionError

num = 10
result = num/0
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1352/1519918701.py in <cell line: 0>()
#       2
#       3 num = 10
# ----> 4 result = num/0
#       5 print(result)
#
# ZeroDivisionError: division by zero

# %%
# TypeError
num = 10
text = "5"

result = num + text
TypeError
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1352/4111433145.py in <cell line: 0>()
#       3 text = "5"
#       4
# ----> 5 result = num + text
#       6 TypeError
#       7 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# IndexError
numbers = [10,20,30]

print(numbers[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1352/2609905563.py in <cell line: 0>()
#       2 numbers = [10,20,30]
#       3
# ----> 4 print(numbers[5])
#
# IndexError: list index out of range

# %%
# KeyError
student = {"name":"Bibek","age":21}

print(student["address"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1352/1598722405.py in <cell line: 0>()
#       2 student = {"name":"Bibek","age":21}
#       3
# ----> 4 print(student["address"])
#
# KeyError: 'address'

# %%
# FileNotFoundError
file = open("data.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1352/3601326219.py in <cell line: 0>()
#       1 # FileNotFoundError
# ----> 2 file = open("data.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
try:
  file = open("sample.txt","r")
  content = file.read()
except FileNotFoundError:
  print("Error: File not found!")
else:
  print("File content:", content)
finally:
  # This will always run
  print("File closed.")
# Out:
# Error: File not found!
# File closed.

# %%
def set(age):
  if age < 0:
    raise ValueError("Age cannot be negative")
  print(f"Age set to {age}")

# %%
try:
  set(5)
except ValueError as e:
  print(e)
# Out:
# Age set to 5

# %%
# Custom Exception
class InvalidAgeError(Exception):
  """Custom exception for invalid age values"""
  pass

def set_age_custom(age):
  if age > 120:
    raise InvalidAgeError("Age cannot be over 120")

# %%
set_age_custom(124)
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# /tmp/ipykernel_1352/560963531.py in <cell line: 0>()
# ----> 1 set_age_custom(124)
#
# /tmp/ipykernel_1352/979186185.py in set_age_custom(age)
#       6 def set_age_custom(age):
#       7   if age > 120:
# ----> 8     raise InvalidAgeError("Age cannot be over 120")
#
# InvalidAgeError: Age cannot be over 120
