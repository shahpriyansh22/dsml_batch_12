# %%
# lists
# slicing
# len
# append
# extend
# insert
# count
# remove
# pop
# clear
# copy (shallow and deep copy)
# stack
# queue

# %%
data = (1,2,3,4,5)
data
# Out:
# (1, 2, 3, 4, 5)

# %%
type(data)
# Out:
# tuple

# %%
data2_ = [1,2,3,4,5]
type(data2_)
# Out:
# list

# %%
data3 = tuple(data2_)
type(data3)
# Out:
# tuple

# %%
type(list(data3))
# Out:
# list

# %%
data = (1,2,3,4,5)
print(max(data))
# Out:
# 5

# %%
numbers = (2, -5, 0, -1)

print(any(x > 0 for x in numbers))
# Out:
# True

# %%
# any(email, username)
# any(phone, email)

# %%
numbers = (2, 5, 1, -1)

print(all(x > 0 for x in numbers))
# Out:
# False

# %%
# dimession = w *h*d (w, h, d)
#Tuples packing in python

data_pack = 1, 2.0, 'three'
data_pack
# Out:
# (1, 2.0, 'three')

# %%
# tuples unpacking in python
a,b,c = data_pack

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2.0

# %%
c
# Out:
# 'three'

# %%
a,b,c = data_pack

# %%
data_pack = 1, 2.0, 'three'
a,b, _ = data_pack  #(w *h*d) only 2 dimession chahiyo

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2.0

# %%
_
# Out:
# 2.0

# %%
t = (10,20,30) #indexing
print(t[1])
# Out:
# 20

# %%
#slicing
print(t[1:3])
# Out:
# (20, 30)

# %%
#concatentation

t1 = (1,2)
t2 = (3,4)
print(t1 +t2)
# Out:
# (1, 2, 3, 4)

# %%
#repetitions

print(t1*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
t = (10,20,30,40)
print(20 in t)
# Out:
# True

# %%
t1 = (1,2)
t2 = (1,3)
print(t1>t2)
# Out:
# False

# %%
t1 = (1,2)
t2 = (1,3)
print(t1<t2)
# Out:
# True

# %%
t1 = (1,2)
t2 = (1,2)
print(t1==t2)
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#delete in list
lst = [10, 30, 40,50]
del lst[1]
lst
# Out:
# [10, 40, 50]

# %%
#delete in tuple
lst = [10, 30, 40,50]
del lst[1]

# %%
# pack and unpack
# list ma gareka  ..apend, extend, del, ...(jun le tuple lai alter garcha tyo garna mildaina)

# (10,20,30)
# (10,20)
# (10,20,30,40)

# %%
lst = (10, 30, 40,50)
del lst

# %%
# lst
# "It says NameError: name 'lst' is not defined"

# %%
#set

data = {1,2,3,4,5}

# %%
type(data)
# Out:
# set

# %%
data2 = {1,2,3,4,5,1,2}
data2
# Out:
# {1, 2, 3, 4, 5}

# %%
data3 = {}
type(data3)
# Out:
# dict

# %%
data5 = [1,2,3,4,5,6,7,4,5,3,2,4,5]
set(data5)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
type(set(data5))
# Out:
# set

# %%
# | union
# & intersection
# - difference

# (A-B)|(B-A)

# %%
A = {1,2,3,4,5}
B= {4,5,6,7,8}

# %%
A-B #difference
# Out:
# {1, 2, 3}

# %%
A | B #union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A & B #intersection
# Out:
# {4, 5}

# %%
A ^ B  #symmetric difference
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
(A-B) | (B-A) #symmetric Difference
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
# membership (in)
print(2 in A)
# Out:
# True

# %%
# membership (in)
print("Ram" in A)
# Out:
# False

# %%
# subset
A = {1,2,4,5}
B= {1,2,3,5,4,6}
print(A <=B)
# Out:
# True

# %%
# subset
A = {1,2,4,5, 7}
B= {1,2,3,5,4,6}
print(A <=B)
# Out:
# False
