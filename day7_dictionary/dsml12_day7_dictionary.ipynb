# %%
# tuples and set

# packing and unpacking
# tuple operation
# min max sum index, slicing, concat, repetition, membership, comparision

# set
# union intersection diff, sym diff, ...

# %%
# {
#     key: value
# }

# %%
dict_ = {
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000
}

# %%
type(dict_)
# Out:
# dict

# %%
dict() # using constructor method

dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000
})

# %%
dict_data
# Out:
# {'name': 'Priyansh', 'address': 'Kathmandu', 'phone': 9800000000}

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "name": "Ram"
})

# %%
dict_data
# Out:
# {'name': 'Ram', 'address': 'Kathmandu', 'phone': 9800000000}

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "courses": ['dsml', 'python', 'ML']
})

# %%
# key => unique
# value => no unique

dict_data['name']
# Out:
# 'Priyansh'

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "courses": ['dsml', 'python', 'ML']
})

# %%
person = dict([("name", "Priyansh"), ("Address", "Kathmandu")])
person
# Out:
# {'name': 'Priyansh', 'Address': 'Kathmandu'}

# %%
dict_new = {
    1: "apple",
    2: "ball"
}

# %%
dict_new
# Out:
# {1: 'apple', 2: 'ball'}

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "courses": ['dsml', 'python', 'ML']
})

# %%
dict_data["courses"]
# Out:
# ['dsml', 'python', 'ML']

# %%
dict_data.get("courses")
# Out:
# ['dsml', 'python', 'ML']

# %%
# phone number correction
dict_data["phone"] = 9811111111

# %%
dict_data
# Out:
# {'name': 'Priyansh',
#  'address': 'Kathmandu',
#  'phone': 9811111111,
#  'courses': ['dsml', 'python', 'ML']}

# %%
dict_data.keys()
# Out:
# dict_keys(['name', 'address', 'phone', 'courses'])

# %%
dict_data.values()
# Out:
# dict_values(['Priyansh', 'Kathmandu', 9811111111, ['dsml', 'python', 'ML']])

# %%
dict_data.items()
# Out:
# dict_items([('name', 'Priyansh'), ('address', 'Kathmandu'), ('phone', 9811111111), ('courses', ['dsml', 'python', 'ML'])])

# %%
dict_data.pop('name')
# Out:
# 'Priyansh'

# %%
dict_data
# Out:
# {'address': 'Kathmandu',
#  'phone': 9811111111,
#  'courses': ['dsml', 'python', 'ML']}

# %%
# If not found, it displays "Not found" message
dict_data.pop("name", "Not found")
# Out:
# 'Not found'

# %%
dict_data.pop("address", "Not found")
# Out:
# 'Kathmandu'

# %%
dat_int = {
    1:12345,
    2:34567
}
dat_int
# Out:
# {1: 12345, 2: 34567}

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "courses": ['dsml', 'python', 'ML']
})

# %%
dict_data.popitem()
# Out:
# ('courses', ['dsml', 'python', 'ML'])

# %%
dict_data
# Out:
# {'name': 'Priyansh', 'address': 'Kathmandu', 'phone': 9800000000}

# %%
del dict_data['name']

# %%
dict_data
# Out:
# {'address': 'Kathmandu', 'phone': 9800000000}

# %%
dict_data.clear()

# %%
dict_data
# Out:
# {}

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "courses": ['dsml', 'python', 'ML']
})

# %%
del dict_data

# %%
# dict_data "name 'dict_data' is not defined"

# %%
# what is the difference between pop in list or tuple and pop in dictionary?
lst = [1,2,3,4,5]
lst.pop()
# Out:
# 5

# %%
dict_ = {
    "name": "abcd",
    "address": "ktm",
    "phone": 978
}

# %%
dict_.pop("name", "Not found")
# Out:
# 'abcd'

# %%
# creating two dictionaries
dict1 = {
    "name": "Ram",
    "address": "Ktm",
    "age": 20
}
dict1
# Out:
# {'name': 'Ram', 'address': 'Ktm', 'age': 20}

# %%
dict2 = {
    "phone": 98766,
    "skill": "DSML"
}
dict2
# Out:
# {'phone': 98766, 'skill': 'DSML'}

# %%
dict1.update(dict2)

# %%
dict1
# Out:
# {'name': 'Ram', 'address': 'Ktm', 'age': 20, 'phone': 98766, 'skill': 'DSML'}

# %%
dict2
# Out:
# {'phone': 98766, 'skill': 'DSML'}

# %%
dict1 = {
    "name": "Ram",
    "address": "Ktm",
    "age": 20
}
dict1
# Out:
# {'name': 'Ram', 'address': 'Ktm', 'age': 20}

# %%
dict2 = {
    "name": "Hari",
    "address": "Pkr",
    "age": 24
}
dict2
# Out:
# {'name': 'Hari', 'address': 'Pkr', 'age': 24}

# %%
dict1.update(dict2)

# %%
dict1
# Out:
# {'name': 'Hari', 'address': 'Pkr', 'age': 24}

# %%
dict2
# Out:
# {'name': 'Hari', 'address': 'Pkr', 'age': 24}

# %%
# three dictionaries
dict1 = {
    "name": "Ram",
    "address": "Ktm",
    "age": 20
}
dict1
# Out:
# {'name': 'Ram', 'address': 'Ktm', 'age': 20}

# %%
dict2 = {
    "phone": 98766,
    "skill": "DSML"
}
dict2
# Out:
# {'phone': 98766, 'skill': 'DSML'}

# %%
dict1.update(dict2)

# %%
dict1
# Out:
# {'name': 'Ram', 'address': 'Ktm', 'age': 20, 'phone': 98766, 'skill': 'DSML'}

# %%
dict2
# Out:
# {'phone': 98766, 'skill': 'DSML'}

# %%
dict3 = {
    "gender": "Male",
    "marks": 80
}

# %%
dict4 = {
    "nationality": "Nepalese",
    "language": "Nepali"
}

# %%
student_dict = {**dict1, **dict2, **dict3, **dict4} # using **kwargs to unpack
student_dict
# Out:
# {'name': 'Ram',
#  'address': 'Ktm',
#  'age': 20,
#  'phone': 98766,
#  'skill': 'DSML',
#  'gender': 'Male',
#  'marks': 80,
#  'nationality': 'Nepalese',
#  'language': 'Nepali'}

# %%
# arranging in order
result = sorted(student_dict)
result
# Out:
# ['address',
#  'age',
#  'gender',
#  'language',
#  'marks',
#  'name',
#  'nationality',
#  'phone',
#  'skill']

# %%
student = {"b": 2, "a": 1, "c": 3}
result = sorted(student)
result
# Out:
# ['a', 'b', 'c']

# %%
# merge Dicts
dict1 | dict2 | dict3
# Out:
# {'name': 'Ram',
#  'address': 'Ktm',
#  'age': 20,
#  'phone': 98766,
#  'skill': 'DSML',
#  'gender': 'Male',
#  'marks': 80}

# %%
len(dict1)
# Out:
# 5

# %%
dict_data = dict({
    "name": "Priyansh",
    "address": "Kathmandu",
    "phone": 9800000000,
    "courses": ['dsml', 'python', 'ML']
})

# %%
len(dict_data)
# Out:
# 4

# %%
dict_data
# Out:
# {'name': 'Priyansh',
#  'address': 'Kathmandu',
#  'phone': 9800000000,
#  'courses': ['dsml', 'python', 'ML']}

# %%
dict_data.setdefault("name", "this is hello")
# Out:
# 'Priyansh'

# %%
dict_data.keys()
# Out:
# dict_keys(['name', 'address', 'phone', 'courses'])

# %%
dict_data.setdefault("address", "set the default value")
# Out:
# 'Kathmandu'

# %%
# adding default value
dict_data.setdefault("age", "50")
# Out:
# '50'

# %%
dict_data
# Out:
# {'name': 'Priyansh',
#  'address': 'Kathmandu',
#  'phone': 9800000000,
#  'courses': ['dsml', 'python', 'ML'],
#  'age': '50'}

# %%
# checking for the key in the dictionary
"status" in dict_data.keys()
# Out:
# False

# %%
"age" in dict_data.keys()
# Out:
# True

# %%
dict_ = {
    "A": 30,
    "B": 35,
    "C": 20
}
print(max(dict_.values()))
print(min(dict_.values()))
# Out:
# 35
# 20

# %%
# class task "slide page 19"
# 1
dict_class = {
    "std name": "Abc",
    "age": 20,
    "faculty": "DSML"
}
dict_class
# Out:
# {'std name': 'Abc', 'age': 20, 'faculty': 'DSML'}

# %%
# 2
dict_class["phone"] = "9800000000"
dict_class
# Out:
# {'std name': 'Abc', 'age': 20, 'faculty': 'DSML', 'phone': '9800000000'}

# %%
# 3
dict_class["age"] = 22
dict_class
# Out:
# {'std name': 'Abc', 'age': 22, 'faculty': 'DSML', 'phone': '9800000000'}

# %%
# 4
# del dict_class["city"]
# dict_class

# %%
# 5
if "email" in dict_class:
    print("Email key exists")
else:
    print("Email key does not exist")
# Out:
# Email key does not exist
