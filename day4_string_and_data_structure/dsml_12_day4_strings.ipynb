# %%
data = "hello"
data1 = 'hello'

# %%
type(data)
# Out:
# str

# %%
type(data1)
# Out:
# str

# %%
data = "Python"

# %%
data[0]
# Out:
# 'P'

# %%
data[-6]
# Out:
# 'P'

# %%
data = "hello's, i am a boy"
data
# Out:
# "hello's, i am a boy"

# %%
data = 'this is a "boy"'
data
# Out:
# 'this is a "boy"'

# %%
# data = 'hello's, i am a boy'
# data

# %%
'''hello'''
# Out:
# 'hello'

# %%
"""hello"""
# Out:
# 'hello'

# %%
data + " " + data1
# Out:
# 'this is a "boy" hello'

# %%
data2 = "Priyansh"
data3 = "Shah"

result = data2 + data3

# %%
result
# Out:
# 'PriyanshShah'

# %%
result = data2 + " " + data3
result
# Out:
# 'Priyansh Shah'

# %%
data2 * 3
# Out:
# 'PriyanshPriyanshPriyansh'

# %%
data_ = "python"

# %%
data_
# Out:
# 'python'

# %%
data_[1]
# Out:
# 'y'

# %%
data_[-2]
# Out:
# 'o'

# %%
data_[1:4]
# Out:
# 'yth'

# %%
data_new = "hello, i am from these class"
data_new[2:20:2]

# [start:end:step]
# Out:
# 'lo  mfo h'

# %%
data = "Python" #result Py
data[0:2]
# Out:
# 'Py'

# %%
data[:-4]
# Out:
# 'Py'

# %%
# hon
data[3:]
# Out:
# 'hon'

# %%
data[::]
# Out:
# 'Python'

# %%
data[::-1]
# Out:
# 'nohtyP'

# %%
# given string "Interview"
# result = weivretnI
data = "Interview"
data[::-1]
# Out:
# 'weivretnI'

# %%
data_new = "hello, i am from these class"
len(data_new)
# Out:
# 28

# %%
string = "hello"
string.upper()
# Out:
# 'HELLO'

# %%
string1 = "HELLO"
string1.lower()
# Out:
# 'hello'

# %%
string1.title()
# Out:
# 'Hello'

# %%
# strip
# removes leading and trailing whitespace
text = "     Hello world     "
text.strip()
# Out:
# 'Hello world'

# %%
text = "####Python####"
text.strip("#")
# Out:
# 'Python'

# %%
# replace
text = "I like java"
text.replace("java", "python")
# Out:
# 'I like python'

# %%
# split
text = "apple, banana, mango"
text.split()
# Out:
# ['apple,', 'banana,', 'mango']

# %%
text = "apple, banana, mango"
print(type(text))
data1 = text.split(",")
print(data1)
print(type(data1))
# text.split(",")
# Out:
# <class 'str'>
# ['apple', ' banana', ' mango']
# <class 'list'>

# %%
text = "apple, banana, mango" # splits a string into a list
text.split("a")
# Out:
# ['', 'pple, b', 'n', 'n', ', m', 'ngo']

# %%
# join()
letters = ["P","Y","T","H","O","N"] # list
print("".join(letters))
# Out:
# PYTHON

# %%
letters = ["P","Y","T","H","O","N"] # list
print(" ".join(letters))
# Out:
# P Y T H O N

# %%
letters = ["P","Y","T","H","O","N"] # list
print(type(letters))
data5 = " ".join(letters)
data5
# Out:
# <class 'list'>
# 'P Y T H O N'

# %%
type(data5)
# Out:
# str

# %%
text = "I like java"
text.endswith("java")
# Out:
# True

# %%
text = "data.pdf"
text.endswith("java")
# Out:
# False

# %%
# git
# numbers
# string and string operation
