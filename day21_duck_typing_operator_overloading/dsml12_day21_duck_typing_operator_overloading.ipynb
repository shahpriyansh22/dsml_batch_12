# %%
# payment
# - esewapayment
# payment()
# - khalti payment
# payment()

# %%
# Operator polymorphism(+)
a = "hello"
b = "world"
a + b
# Out:
# 'helloworld'

# %%
# Operator polymorphism(+)
a = 4
b = 6
a + b
# Out:
# 10

# %%
# built in polymorphism

print(len("Python"))
# Out:
# 6

# %%
print(len([1,2,3,4,5,6,7]))
# Out:
# 7

# %%
# Method  overriding

class PaymentGateway:
    def process_payment(self, amount):
        pass

class CreditCard(PaymentGateway):
    def process_payment(self, amount):
        return f"Processing ${amount} via Credit Card authentication."

class PayPal(PaymentGateway):
    def process_payment(self, amount):
        return f"Processing ${amount} via PayPal secure token."

# Unified interface function
def execute_checkout(payment_method, amount):
    print(payment_method.process_payment(amount))

# Usage
card = CreditCard()
wallet = PayPal()

execute_checkout(card, 250)
execute_checkout(wallet, 250)
# Out:
# Processing $250 via Credit Card authentication.
# Processing $250 via PayPal secure token.

# %%
# Duck Typing
class Duck:
  def swim(self):
    return "Duck swimming"
  def fly(self):
    return "Duck flying"

# %%
class Airplane:
  def fly(self):
    return "Airplane Fly"

# %%
def fly_test(entity):
  return entity.fly()

# %%
# create object
duck = Duck()
airplane = Airplane()

# %%
# same function works with different object
fly_test(duck)
# Out:
# 'Duck flying'

# %%
fly_test(airplane)
# Out:
# 'Airplane Fly'

# %%
class Esewa:
  def payment(self,amount):
    return f"Esewa paying:{amount}"

class Khalti:
  def payment(self,amount):
    return f"Khalti paying:{amount}"

class Banktransfer:
  def payment(self,amount):
    return f"Bank transfer paying:{amount}"

# %%
def pay_test_method(entity,amount):
  return entity.payment(amount)

# %%
e = Esewa()
k = Khalti()
b = Banktransfer()

# %%
pay_test_method(e,250)
# Out:
# 'Esewa paying:250'

# %%
pay_test_method(k,250)
# Out:
# 'Khalti paying:250'

# %%
pay_test_method(b,250)
# Out:
# 'Bank transfer paying:250'

# %%
# Operator overloading

class Point:
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def __add__(self,other):
    x = self.x + other.x
    y = self.y + other.y
    return Point(x,y)

  def __sub__(self,other):
    x = self.x - other.x
    y = self.y - other.y
    return Point(x,y)
  def __mul__(self,other):
    x = self.x * other.x
    y = self.y * other.y
    return Point(x,y)

  def __str__(self):
    return f"({self.x},{self.y})"

# %%
# Create point object

p1 = Point(1,2)
p2 = Point(3,4)

# %%
p3 = p1 + p2
print(p3)
# Out:
# (4,6)

# %%
p4 = p1 - p2
print(p4)
# Out:
# (-2,-2)

# %%
# Operator overloading

class Point:
  def __init__(self,x):
    self.x = x

  def __mul__(self,other):
    x = self.x * other.x
    return Point(x)

  def __str__(self):
    return f"({self.x})"

p5 = Point(6)
p6 = Point(7)
p7 = p5 * p6
print(p7)
# Out:
# (42)

# %%
import operator

a = 10
b = 5
print(operator.add(a,b))
print(operator.__add__(a,b))
# Out:
# 15
# 15

# %%
class data:
  def physic(self):
    print("physic")

# %%
c = data()
c.physic()
# Out:
# physic
