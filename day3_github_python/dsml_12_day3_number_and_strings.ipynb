# %%
a = 5

# %%
a
# Out:
# 5

# %%
#key value pair
data = {
    "name": "Ram"
}

# %%
data
# Out:
# {'name': 'Ram'}

# %%
1,2,3,4 #integer
1.3,4.5 #float
2+3j #complex
# Out:
# (2+3j)

# %%
#integer

#  1 (positive integer)
# -1 (negative integer)

# %%
a = 5

# %%
type(5)
# Out:
# int

# %%
pie = 22/7

# %%
pie
# Out:
# 3.142857142857143

# %%
type(pie)
# Out:
# float

# %%
data = 3+2j

# %%
data
# Out:
# (3+2j)

# %%
type(data)
# Out:
# complex

# %%
age = 20.4

#type conversion

# %%
age = int(age)
age
# Out:
# 20

# %%
income = 200
new_income = float(income)
new_income
# Out:
# 200.0

# %%
type(new_income)
# Out:
# float

# %%
new_income = str(new_income)
new_income
# Out:
# '200.0'

# %%
type(new_income)
# Out:
# str

# %%
3/2
# Out:
# 1.5

# %%
3%2
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
11//3
# Out:
# 3

# %%
a = 3
b = 3
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
type(a == b)
# Out:
# bool

# %%
import math

# %%
math.floor(44.4)
# Out:
# 44

# %%
math.ceil(44.1)
# Out:
# 45

# %%
math.gcd(3,6,9,12)
# Out:
# 3

# %%
user = 640
capacity = 128
result = max(user, capacity)

# %%
result
# Out:
# 640

# %%
round(22.3345, 2)
# Out:
# 22.33

# %%
round(22.3365, 2)
# Out:
# 22.34
