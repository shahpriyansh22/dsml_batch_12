# %%
dict ={
    "name":"Priyansh",
    "Rollnumber": 20
}

# %%
dict.values()
# Out:
# dict_values(['Priyansh', 20])

# %%
dict.get("name")
# Out:
# 'Priyansh'

# %%
# Recursion: Recursion is a programming technique where a function calls itself, until a stopping condition

# %% [markdown]
# # # Recursion
# # Recursion is a programming technique where a function calls itself, until a stopping condition
#
#  1) Base case (stopping condition)
#  2) Recursive case

# %%
# Factorial number

# 5! = 5*4*3*2*1
# fact(n) * fact(n-1)

# %%
def condition(n):
  if n==0 or n==1: #base case
    return 1
  return n*condition(n-1) #recursive case

# %%
condition(5)
# Out:
# 120

# %%
# 1, 1, 2, 3, 5, 8, 13, 21,

# %%
# Decorator

def decorator(func):
  def wrapper():
    print("Before")
    func()
    print("After")
  return wrapper

# %%
def hello():
  print("Hello World")

# %%
func = decorator(hello)
func()
# Out:
# Before
# Hello World
# After

# %%
# Decorator

def decorator(func):
  def wrapper():
    print("Before")
    func()
    print("After")
  return wrapper

@decorator
def hello1():
  print("Hello World")

# %%
hello1()
# Out:
# Before
# Hello World
# After

# %% [markdown]
# Write a decorator login_required that checks whether a user is logged in. If the variable logged_in is True, execute the function; otherwise, print "Access Denied".

# %%
def login_required(func):

  def wrapper():
    logined_in = True

    if logined_in:
      func()
    else:
      print("Access Denied")
  return wrapper

@login_required
def dashboard():
  print("Welcome to dashboard")

# %%
dashboard()
# Out:
# Welcome to dashboard

# %%
# Inheritance in Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class A:
  def display(self):
    print("Hello from base class")

# %%
class B(A):
  def dislpay_B(self):
    print("Hello i am from derived class")

# %%
obj = B()
obj.display()
obj.dislpay_B()
# Out:
# Hello from base class
# Hello i am from derived class

# %% [markdown]
# Method Resolution Order (MRO) is the deterministic sequence Python uses to search for methods or attributes in a class hierarchy

# %%
class A:
    def show(self):
        print("A")
    def dsml12(self):
      print("hello dsml")


class B(A):
    def show(self):
        print("B")
        super().show()


class C(A):
    def show(self):
        print("C")
        super().show()


class D(B, C):
    def show(self):
        print("D")
        super().show()


obj = D()
obj.show()
# Out:
# D
# B
# C
# A

# %%
dir(A)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'dsml12',
#  'show']

# %%
# args and kwargs

# %%
# args = position argument
# kwargs = keyword argument

# %%
class Dsml:

  def show(self,x,*args,**kwargs):
    print(x)
    print(args)
    print(kwargs)

# %%
obj = Dsml()
obj.show(20,[1,2,3,4,5,], a=20)
# Out:
# 20
# ([1, 2, 3, 4, 5],)
# {'a': 20}

# %%
# Iterator and generator in python

# Every generator is an iterator, but not every iterator is a generator. Both are tools used to implement lazy evaluation

# %%
class Count:

  def __init__(self, limit):
    self.num = 1
    self.limit = limit

  def __iter__(self):
    return self

  def __next__(self):
    if self.num <= self.limit:
      value = self.num
      self.num += 1
      return value
    else:
      raise StopIteration

# %%
counter = Count(5)

# %%
for i in counter:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Generator
# A generator is a simpler way to create an iterator using the yield keyword.

def count(limit):

    num = 1

    while num <= limit:
        yield num
        num += 1


counter = count(5)

for i in counter:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def numbers():

    for i in range(1, 6):
        yield i


g = numbers()

print(next(g))
print(next(g))
# Out:
# 1
# 2

# %%
# Only one value is generated at a time, making generators memory-efficient for large datasets.
